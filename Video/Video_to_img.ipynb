# %%
import cv2
import os

# %%
# Function to extract frames from a video until reaching the desired frame count
def extract_frames(video_file):
    cap = cv2.VideoCapture(video_file)
    
    frame_rate = 0.5  # Desired frame rate (1 frame every 0.5 seconds)
    frame_count = 0
    
    # Get the video file's name without extension
    video_name = os.path.splitext(os.path.basename(video_file))[0]
    
    # Create an output folder with a name corresponding to the video
    output_directory = f"{video_name}_frames"
    os.makedirs(output_directory, exist_ok=True)
    
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        frame_count += 1
        
        # Only extract frames at the desired frame rate
        if frame_count % int(cap.get(5) / frame_rate) == 0:
            output_file = f"{output_directory}/frame_{frame_count}.jpg"

            cv2.imwrite(output_file, frame)
            print(f"Frame {frame_count} has been extracted and saved as {output_file}")
    
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    video_file = r"E:\VS_Code\ZHAW\ML2\Vision\Video\Video_tests\warsaw.mp4"  # Replace with your video's name
    
    extract_frames(video_file)
# Out:
# Frame 60 has been extracted and saved as warsaw_frames/frame_60.jpg
# Frame 120 has been extracted and saved as warsaw_frames/frame_120.jpg
# Frame 180 has been extracted and saved as warsaw_frames/frame_180.jpg
# Frame 240 has been extracted and saved as warsaw_frames/frame_240.jpg
# Frame 300 has been extracted and saved as warsaw_frames/frame_300.jpg
# Frame 360 has been extracted and saved as warsaw_frames/frame_360.jpg
# Frame 420 has been extracted and saved as warsaw_frames/frame_420.jpg
# Frame 480 has been extracted and saved as warsaw_frames/frame_480.jpg
# Frame 540 has been extracted and saved as warsaw_frames/frame_540.jpg
# Frame 600 has been extracted and saved as warsaw_frames/frame_600.jpg
# Frame 660 has been extracted and saved as warsaw_frames/frame_660.jpg
# Frame 720 has been extracted and saved as warsaw_frames/frame_720.jpg
# Frame 780 has been extracted and saved as warsaw_frames/frame_780.jpg
# Frame 840 has been extracted and saved as warsaw_frames/frame_840.jpg
# Frame 900 has been extracted and saved as warsaw_frames/frame_900.jpg
# Frame 960 has been extracted and saved as warsaw_frames/frame_960.jpg
# Frame 1020 has been extracted and saved as warsaw_frames/frame_1020.jpg
# Frame 1080 has been extracted and saved as warsaw_frames/frame_1080.jpg
# Frame 1140 has been extracted and saved as warsaw_frames/frame_1140.jpg
# Frame 1200 has been extracted and saved as warsaw_frames/frame_1200.jpg
# Frame 1260 has been extracted and saved as warsaw_frames/frame_1260.jpg
# Frame 1320 has been extracted and saved as warsaw_frames/frame_1320.jpg
# Frame 1380 has been extracted and saved as warsaw_frames/frame_1380.jpg
# Frame 1440 has been extracted and saved as warsaw_frames/frame_1440.jpg
# Frame 1500 has been extracted and saved as warsaw_frames/frame_1500.jpg
# Frame 1560 has been extracted and saved as warsaw_frames/frame_1560.jpg
# Frame 1620 has been extracted and saved as warsaw_frames/frame_1620.jpg
# Frame 1680 has been extracted and saved as warsaw_frames/frame_1680.jpg
# Frame 1740 has been extracted and saved as warsaw_frames/frame_1740.jpg
# Frame 1800 has been extracted and saved as warsaw_frames/frame_1800.jpg
# Frame 1860 has been extracted and saved as warsaw_frames/frame_1860.jpg
# Frame 1920 has been extracted and saved as warsaw_frames/frame_1920.jpg
# Frame 1980 has been extracted and saved as warsaw_frames/frame_1980.jpg
# Frame 2040 has been extracted and saved as warsaw_frames/frame_2040.jpg
# Frame 2100 has been extracted and saved as warsaw_frames/frame_2100.jpg
# Frame 2160 has been extracted and saved as warsaw_frames/frame_2160.jpg
# Frame 2220 has been extracted and saved as warsaw_frames/frame_2220.jpg
# Frame 2280 has been extracted and saved as warsaw_frames/frame_2280.jpg
# Frame 2340 has been extracted and saved as warsaw_frames/frame_2340.jpg
# Frame 2400 has been extracted and saved as warsaw_frames/frame_2400.jpg
# Frame 2460 has been extracted and saved as warsaw_frames/frame_2460.jpg
# Frame 2520 has been extracted and saved as warsaw_frames/frame_2520.jpg
# Frame 2580 has been extracted and saved as warsaw_frames/frame_2580.jpg
# Frame 2640 has been extracted and saved as warsaw_frames/frame_2640.jpg
# Frame 2700 has been extracted and saved as warsaw_frames/frame_2700.jpg
# Frame 2760 has been extracted and saved as warsaw_frames/frame_2760.jpg
# Frame 2820 has been extracted and saved as warsaw_frames/frame_2820.jpg
# Frame 2880 has been extracted and saved as warsaw_frames/frame_2880.jpg
# Frame 2940 has been extracted and saved as warsaw_frames/frame_2940.jpg
# Frame 3000 has been extracted and saved as warsaw_frames/frame_3000.jpg
# Frame 3060 has been extracted and saved as warsaw_frames/frame_3060.jpg
# Frame 3120 has been extracted and saved as warsaw_frames/frame_3120.jpg
# Frame 3180 has been extracted and saved as warsaw_frames/frame_3180.jpg
# Frame 3240 has been extracted and saved as warsaw_frames/frame_3240.jpg
# Frame 3300 has been extracted and saved as warsaw_frames/frame_3300.jpg
# Frame 3360 has been extracted and saved as warsaw_frames/frame_3360.jpg
# Frame 3420 has been extracted and saved as warsaw_frames/frame_3420.jpg
# Frame 3480 has been extracted and saved as warsaw_frames/frame_3480.jpg
# Frame 3540 has been extracted and saved as warsaw_frames/frame_3540.jpg
# Frame 3600 has been extracted and saved as warsaw_frames/frame_3600.jpg
# Frame 3660 has been extracted and saved as warsaw_frames/frame_3660.jpg
# Frame 3720 has been extracted and saved as warsaw_frames/frame_3720.jpg
# Frame 3780 has been extracted and saved as warsaw_frames/frame_3780.jpg
# Frame 3840 has been extracted and saved as warsaw_frames/frame_3840.jpg
# Frame 3900 has been extracted and saved as warsaw_frames/frame_3900.jpg
# Frame 3960 has been extracted and saved as warsaw_frames/frame_3960.jpg
# Frame 4020 has been extracted and saved as warsaw_frames/frame_4020.jpg
# Frame 4080 has been extracted and saved as warsaw_frames/frame_4080.jpg
# Frame 4140 has been extracted and saved as warsaw_frames/frame_4140.jpg
# Frame 4200 has been extracted and saved as warsaw_frames/frame_4200.jpg
# Frame 4260 has been extracted and saved as warsaw_frames/frame_4260.jpg
# Frame 4320 has been extracted and saved as warsaw_frames/frame_4320.jpg
# Frame 4380 has been extracted and saved as warsaw_frames/frame_4380.jpg
# Frame 4440 has been extracted and saved as warsaw_frames/frame_4440.jpg
# Frame 4500 has been extracted and saved as warsaw_frames/frame_4500.jpg
# Frame 4560 has been extracted and saved as warsaw_frames/frame_4560.jpg
# Frame 4620 has been extracted and saved as warsaw_frames/frame_4620.jpg
# Frame 4680 has been extracted and saved as warsaw_frames/frame_4680.jpg
# Frame 4740 has been extracted and saved as warsaw_frames/frame_4740.jpg
# Frame 4800 has been extracted and saved as warsaw_frames/frame_4800.jpg
# Frame 4860 has been extracted and saved as warsaw_frames/frame_4860.jpg
# Frame 4920 has been extracted and saved as warsaw_frames/frame_4920.jpg
# Frame 4980 has been extracted and saved as warsaw_frames/frame_4980.jpg
